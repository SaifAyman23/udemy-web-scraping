# %%
import pandas as pd
import numpy as np

# %%
courses_list = []
with open("data.txt") as file:
    courses_list = file.read().split("================================")

# %%
courses_list = [x.split("\n") for x in courses_list]
del courses_list[-1]

# %%
data = []
for course in courses_list:
    element = []
    del course[-1]
    
    if course[-1] == "Bestseller":
            course[-1] = "Yes"
    else:
        course.append(np.nan)
    for piece in course:
        if isinstance(piece,str) and (piece in ("Instructor:", "Instructors:", "Current Price", "Original Price", "Current price", "Original price", "") or "Rating:" in piece):
            continue
        
        element.append(piece)
    data.append([element[0],*element[2:]])

# %%
courses = pd.DataFrame(data, columns=["Name", 
                                "Description", 
                                "Instructor", 
                                "Rating", 
                                "Number of Ratings", 
                                "Total Hours", 
                                "Number of Lectures", 
                                "Level", 
                                "Current Price", 
                                "Original Price", 
                                "Bestseller"])
courses
# Out:
#                                                  Name  \
# 0   Machine Learning A-Z: AI, Python & R + ChatGPT...
# 1   Python for Data Science and Machine Learning B...
# 2   The Data Science Course: Complete Data Science...
# 3   R Programming A-Zâ„¢: R For Data Science With ...
# 4   Deep Learning A-Z 2024: Neural Networks, AI & ...
# 5   Statistics for Data Science and Business Analysis
# 6   Artificial Intelligence A-Z 2024: Build 7 AI +...
# 7   Data Science A-Z: Hands-On Exercises & ChatGPT...
# 8   Machine Learning, Data Science and Generative ...
# 9   Python A-Zâ„¢: Python For Data Science With Re...
# 10         Spark and Python for Big Data with PySpark
# 11  Complete A.I. & Machine Learning, Data Science...
# 12               Data Analysis with Pandas and Python
# 13  Machine Learning for Absolute Beginners - Level 1
# 14  LangChain- Develop LLM powered applications wi...
# 15      NLP - Natural Language Processing with Python
#
#                                           Description  \
# 0   Learn to create Machine Learning Algorithms in...
# 1   Learn how to use NumPy, Pandas, Seaborn , Matp...
# 2   Complete Data Science Training: Math, Statisti...
# 3   Learn Programming In R And R Studio. Data Anal...
# 4   Learn to create Deep Learning models in Python...
# 5   Statistics you need in the office: Descriptive...
# 6   Combine the power of Data Science, Machine Lea...
# 7   Learn Data Science step by step through real A...
# 8   Complete hands-on machine learning and GenAI t...
# 9   Programming In Python For Data Analytics And D...
# 10  Learn how to use Spark with Python, including ...
# 11  Learn Data Science, Data Analysis, Machine Lea...
# 12  Analyze data quickly and easily with Python's ...
# 13  Learn the Fundamental Concepts of Artificial I...
# 14  Learn LangChain by building FAST a real world ...
# 15  Learn to use Machine Learning, Spacy, NLTK, Sc...
#
#                                            Instructor Rating  \
# 0   Kirill Eremenko, Hadelin de Ponteves, SuperDat...    4.5
# 1                     Jose Portilla, Pierian Training    4.6
# 2                                         365 Careers    4.6
# 3   Kirill Eremenko, SuperDataScience Team, Ligenc...    4.6
# 4   Kirill Eremenko, Hadelin de Ponteves, SuperDat...    4.6
# 5                                         365 Careers    4.5
# 6   Hadelin de Ponteves, Kirill Eremenko, SuperDat...    4.4
# 7   Kirill Eremenko, SuperDataScience Team, Ligenc...    4.6
# 8   Sundog Education by Frank Kane, Frank Kane, Su...    4.7
# 9   Kirill Eremenko, SuperDataScience Team, Ligenc...    4.6
# 10                    Jose Portilla, Pierian Training    4.5
# 11                      Andrei Neagoie, Daniel Bourke    4.6
# 12                                    Boris Paskhaver    4.7
# 13                                      Idan Gabrieli    4.5
# 14                        Eden Marco | LLM Specialist    4.6
# 15                    Jose Portilla, Pierian Training    4.5
#
#    Number of Ratings       Total Hours Number of Lectures         Level  \
# 0          (191,570)    43 total hours       387 lectures    All Levels
# 1          (147,245)    25 total hours       165 lectures    All Levels
# 2          (146,979)  31.5 total hours       520 lectures    All Levels
# 3           (54,982)  10.5 total hours        80 lectures    All Levels
# 4           (47,041)  22.5 total hours       189 lectures    All Levels
# 5           (45,761)     5 total hours        92 lectures    All Levels
# 6           (42,140)  15.5 total hours       129 lectures    All Levels
# 7           (34,249)    21 total hours       217 lectures    All Levels
# 8           (33,499)  20.5 total hours       147 lectures      Beginner
# 9           (29,044)    11 total hours        73 lectures    All Levels
# 10          (24,838)  10.5 total hours        67 lectures  Intermediate
# 11          (24,648)    44 total hours       384 lectures    All Levels
# 12          (23,290)  19.5 total hours       141 lectures    All Levels
# 13          (22,278)   4.5 total hours        59 lectures      Beginner
# 14          (20,213)   9.5 total hours        80 lectures  Intermediate
# 15          (18,185)  11.5 total hours        80 lectures  Intermediate
#
#    Current Price Original Price Bestseller
# 0      EÂ£249.99    EÂ£2,099.99        Yes
# 1      EÂ£349.99    EÂ£2,799.99        NaN
# 2      EÂ£249.99    EÂ£1,899.99        Yes
# 3      EÂ£349.99    EÂ£2,999.99        Yes
# 4      EÂ£349.99    EÂ£2,599.99        Yes
# 5      EÂ£249.99    EÂ£1,699.99        Yes
# 6      EÂ£299.99    EÂ£2,499.99        Yes
# 7      EÂ£349.99    EÂ£2,799.99        NaN
# 8      EÂ£299.99    EÂ£2,299.99        NaN
# 9      EÂ£299.99    EÂ£2,299.99        NaN
# 10     EÂ£399.99    EÂ£2,799.99        Yes
# 11     EÂ£249.99    EÂ£2,099.99        NaN
# 12     EÂ£299.99    EÂ£2,499.99        Yes
# 13     EÂ£249.99    EÂ£1,299.99        NaN
# 14     EÂ£249.99    EÂ£1,299.99        Yes
# 15     EÂ£399.99    EÂ£3,099.99        Yes

# %%
dataset = courses.to_csv("output.csv", index=False)

# %%
dataset = courses.to_excel("output.xlsx", index=False)
